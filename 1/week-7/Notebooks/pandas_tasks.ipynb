# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.7 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.7 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.7 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.7 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.7 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.7 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.7 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.7 MB 1.8 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

# %%
data = {
    "Name": ["Man", "Max", "Charlie", "Diva", "Kimi"],
    "Age": [22, 27, 25, 30, 19],
    "Score": [77, 87, 78, 90, 87]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0      Man   19     85
# 1      Max   21     78
# 2  Charlie   22     92
# 3       Di   20     88
# 4      Eve   23     75
